# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %%
df = pd.read_csv("SN2023egt.csv", sep="\s+")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f3bbe2987c01> in <module>
# ----> 1 df = pd.read_csv("SN2023egt.csv", sep="\s+")
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#      VARNAMES:    CID        MJD    Tobs  SIM_FLUXCAL   FLUXCAL  FLUXCAL_ERR  \
# 0         OBS:  13513  57025.086  -10.32       384.56  366.0900    103.89000
# 1         OBS:  13513  57030.105   -5.30       656.00  653.0700     56.00600
# 2         OBS:  13513  57037.090    1.68       664.38  649.0800     44.25700
# 3         OBS:  13513  57044.059    8.65       501.70  506.0200     36.05800
# 4         OBS:  13513  57051.051   15.64       301.12  304.3600     28.52300
# ...        ...    ...        ...     ...          ...       ...          ...
# 2045      OBS:  21051  57824.906  131.00         0.00    4.6726      0.18992
# 2046      OBS:  21051  57826.906  133.00         0.00    4.5103      0.18333
# 2047      OBS:  21051  57828.906  135.00         0.00    4.3536      0.17696
# 2048      OBS:  21051  57830.906  137.00         0.00    4.2024      0.17081
# 2049      OBS:  21051  57832.906  139.00         0.00    4.0564      0.16488
#
#       DATAFLAG BAND  CHI2  IFIT
# ...

# %%
df['CID']
# Out:
# 0       13513
# 1       13513
# 2       13513
# 3       13513
# 4       13513
#         ...
# 2045    21051
# 2046    21051
# 2047    21051
# 2048    21051
# 2049    21051
# Name: CID, Length: 2050, dtype: int64

# %%
MJD_DAT_13513_g = []
MJD_SIM_13513_g = []
DATA_13513_g = []
SIM_13513_g = []

MJD_DAT_13513_r = []
MJD_SIM_13513_r = []
DATA_13513_r = []
SIM_13513_r = []

MJD_DAT_13513_i = []
MJD_SIM_13513_i = []
DATA_13513_i = []
SIM_13513_i = []

for index, row in df.iterrows():
    ID = row[1]
    MJD = row[2]
    FLUX = row[5]
    DATAFLAG = row[7]
    FILTER = row[8]
    if ID == 13513:
        if FILTER == 'g':
            if DATAFLAG == 1:
                DATA_13513_g.append(FLUX)
                print(FLUX)
                MJD_DAT_13513_g.append(MJD)
            elif DATAFLAG == 0:
                SIM_13513_g.append(FLUX) 
                MJD_SIM_13513_g.append(MJD)
        elif FILTER == 'r':
            if DATAFLAG == 1:
                DATA_13513_r.append(FLUX)
                MJD_DAT_13513_r.append(MJD)
            elif DATAFLAG == 0:
                SIM_13513_r.append(FLUX) 
                MJD_SIM_13513_r.append(MJD)
        elif FILTER == 'i':
            if DATAFLAG == 1:
                DATA_13513_i.append(FLUX)
                MJD_DAT_13513_i.append(MJD)
            elif DATAFLAG == 0:
                SIM_13513_i.append(FLUX) 
                MJD_SIM_13513_i.append(MJD)
    else:
        print('Not Data or Sim')
# Out:
# 366.09
# 653.07
# 649.08
# 506.02
# 304.36
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# ...

# %%
len(DATA_13513)
plt.plot(MJD_DAT_13513_g,DATA_13513_g, 'g.')
plt.plot(MJD_SIM_13513_g,SIM_13513_g, color = 'green')

plt.plot(MJD_DAT_13513_r,DATA_13513_r, 'r.')
plt.plot(MJD_SIM_13513_r,SIM_13513_r, color = 'red')

plt.plot(MJD_DAT_13513_i,DATA_13513_i, 'b.')
plt.plot(MJD_SIM_13513_i,SIM_13513_i, color = 'blue')

# %%
MJD_DAT_21051_g = []
MJD_SIM_21051_g = []
DATA_21051_g = []
SIM_21051_g = []

MJD_DAT_21051_r = []
MJD_SIM_21051_r = []
DATA_21051_r = []
SIM_21051_r = []

MJD_DAT_21051_i = []
MJD_SIM_21051_i = []
DATA_21051_i = []
SIM_21051_i = []

for index, row in df.iterrows():
    ID = row[1]
    MJD = row[2]
    FLUX = row[5]
    DATAFLAG = row[7]
    FILTER = row[8]
    if ID == 21051:
        if FILTER == 'g':
            if DATAFLAG == 1:
                DATA_21051_g.append(FLUX)
                MJD_DAT_21051_g.append(MJD)
            elif DATAFLAG == 0:
                SIM_21051_g.append(FLUX) 
                MJD_SIM_21051_g.append(MJD)
        elif FILTER == 'r':
            if DATAFLAG == 1:
                DATA_21051_r.append(FLUX)
                MJD_DAT_21051_r.append(MJD)
            elif DATAFLAG == 0:
                SIM_21051_r.append(FLUX) 
                MJD_SIM_21051_r.append(MJD)
        elif FILTER == 'i':
            if DATAFLAG == 1:
                DATA_21051_i.append(FLUX)
                MJD_DAT_21051_i.append(MJD)
            elif DATAFLAG == 0:
                SIM_21051_i.append(FLUX) 
                MJD_SIM_21051_i.append(MJD)
    else:
        print('Not Data or Sim')
# Out:
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# ...

# %%
plt.plot(MJD_DAT_21051_g,DATA_21051_g, 'g.')
plt.plot(MJD_SIM_21051_g,SIM_21051_g, color = 'green')

plt.plot(MJD_DAT_21051_r,DATA_21051_r, 'r.')
plt.plot(MJD_SIM_21051_r,SIM_21051_r, color = 'red')

plt.plot(MJD_DAT_21051_i,DATA_21051_i, 'b.')
plt.plot(MJD_SIM_21051_i,SIM_21051_i, color = 'blue')

# %%
print(DATA_21051_g)
# Out:
# [6.3337, 5.39, 3.8899, 12.382, 12.358, 3.9628, 6.0505, 4.4221, 5.3637, 9.572, 3.26, 3.5114, 4.6655]

# %%
print(max(SIM_21051_g))
# Out:
# 4.5975

# %%
MJD_DAT_15037_g = []
MJD_SIM_15037_g = []
DATA_15037_g = []
SIM_15037_g = []

MJD_DAT_15037_r = []
MJD_SIM_15037_r = []
DATA_15037_r = []
SIM_15037_r = []

MJD_DAT_15037_i = []
MJD_SIM_15037_i = []
DATA_15037_i = []
SIM_15037_i = []

for index, row in df.iterrows():
    ID = row[1]
    MJD = row[2]
    FLUX = row[5]
    DATAFLAG = row[7]
    FILTER = row[8]
    if ID == 15037:
        if FILTER == 'g':
            if DATAFLAG == 1:
                DATA_15037_g.append(FLUX)
                MJD_DAT_15037_g.append(MJD)
            elif DATAFLAG == 0:
                SIM_15037_g.append(FLUX) 
                MJD_SIM_15037_g.append(MJD)
        elif FILTER == 'r':
            if DATAFLAG == 1:
                DATA_15037_r.append(FLUX)
                MJD_DAT_15037_r.append(MJD)
            elif DATAFLAG == 0:
                SIM_15037_r.append(FLUX) 
                MJD_SIM_15037_r.append(MJD)
        elif FILTER == 'i':
            if DATAFLAG == 1:
                DATA_15037_i.append(FLUX)
                MJD_DAT_15037_i.append(MJD)
            elif DATAFLAG == 0:
                SIM_15037_i.append(FLUX) 
                MJD_SIM_15037_i.append(MJD)
    else:
        print('Not Data or Sim')
# Out:
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# Not Data or Sim
# ...

# %%
plt.plot(MJD_DAT_15037_g,DATA_15037_g, 'g.')
plt.plot(MJD_SIM_15037_g,SIM_15037_g, color = 'green')

plt.plot(MJD_DAT_15037_r,DATA_15037_r, 'r.')
plt.plot(MJD_SIM_15037_r,SIM_15037_r, color = 'red')

plt.plot(MJD_DAT_15037_i,DATA_15037_i, 'b.')
plt.plot(MJD_SIM_15037_i,SIM_15037_i, color = 'blue')

# %%
ID_list = np.unique(df['CID'])

# %%
for i in ID_list:
    MJD_DAT_g = []
    MJD_SIM_g = []
    DATA_g = []
    SIM_g = []

    MJD_DAT_r = []
    MJD_SIM_r = []
    DATA_r = []
    SIM_r = []

    MJD_DAT_i = []
    MJD_SIM_i = []
    DATA_i = []
    SIM_i = []
    
    for index, row in df.iterrows():
        ID = row[1]
        MJD = row[2]
        FLUX = row[5]
        DATAFLAG = row[7]
        FILTER = row[8]
        if ID == i:
            if FILTER == 'g':
                if DATAFLAG == 1:
                    DATA_g.append(FLUX)
                    MJD_DAT_g.append(MJD)
                elif DATAFLAG == 0:
                    SIM_g.append(FLUX) 
                    MJD_SIM_g.append(MJD)
            elif FILTER == 'r':
                if DATAFLAG == 1:
                    DATA_r.append(FLUX)
                    MJD_DAT_r.append(MJD)
                elif DATAFLAG == 0:
                    SIM_r.append(FLUX) 
                    MJD_SIM_r.append(MJD)
            elif FILTER == 'i':
                if DATAFLAG == 1:
                    DATA_i.append(FLUX)
                    MJD_DAT_i.append(MJD)
                elif DATAFLAG == 0:
                    SIM_i.append(FLUX) 
                    MJD_SIM_i.append(MJD)
            
        
    plt.figure()
    plt.xlabel('MJD', size = 15)
    plt.ylabel('Flux', size = 15)
    plt.title('Lightcurve for SN' + str(i), size = 18)
    plt.plot(MJD_DAT_g,DATA_g, 'g.')
    plt.plot(MJD_SIM_g,SIM_g, color = 'green', label = 'g')

    plt.plot(MJD_DAT_r,DATA_r, 'r.')
    plt.plot(MJD_SIM_r,SIM_r, color = 'red', label = 'r')

    plt.plot(MJD_DAT_i,DATA_i, 'b.')
    plt.plot(MJD_SIM_i,SIM_i, color = 'blue', label = 'i')
    plt.legend(loc = 'upper right')
